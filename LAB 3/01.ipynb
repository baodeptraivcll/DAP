# %%
from chefboost import Chefboost as chef
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/lenhattung/SP26-AI1904-DAP391m/refs/heads/main/lab_part_3/lab1/lab1/dataset/golf.txt'
df = pd.read_csv(url)
df.head()
# Out:
#     Outlook Temp. Humidity    Wind Decision
# 0     Sunny   Hot     High    Weak       No
# 1     Sunny   Hot     High  Strong       No
# 2  Overcast   Hot     High    Weak      Yes
# 3      Rain  Mild     High    Weak      Yes
# 4      Rain  Cool   Normal    Weak      Yes

# %%
print("ID3 algorithm\n")

#set algorithm
config = {'algorithm': 'ID3'}


#train model on training dataset
print("Train model on traing dataset:")
model = chef.fit(df[:8].copy(), config)

#define x vector for given day
xrow = ['Sunny','Hot','High','Weak']

#make prediction for given day
prediction = chef.predict(model, xrow)
print("Prediction for given day. Should we play? {0}".format(prediction))

c=0
print("\nCompare predictions and expected results on TESTING dataset:")
#prediction on testing data set
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']  
    print(actual,"-",prediction)
    if(actual==prediction):
        c=c+1
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# ID3 algorithm
#
# Train model on traing dataset:
# 26-01-19 08:09:40 - ID3 tree is going to be built...
# 26-01-19 08:09:41 - -------------------------
# 26-01-19 08:09:41 - finished in 1.7659235000610352 seconds
# 26-01-19 08:09:41 - -------------------------
# 26-01-19 08:09:41 - Evaluate train set
# 26-01-19 08:09:41 - -------------------------
# 26-01-19 08:09:41 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:09:41 - Labels: ['No' 'Yes']
# 26-01-19 08:09:41 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:09:41 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# Prediction for given day. Should we play? No
#
# Compare predictions and expected results on TESTING dataset:
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':

# %%
print("C4.5 algorithm\n")

#set algorithm
config = {'algorithm': 'C4.5'}
model = chef.fit(df[:8], config)

#define xrow
xrow  = ['Sunny','Hot','High','Weak']

#make single prediction
prediction = chef.predict(model,xrow)

#prediction on test data set
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    
    print(actual,"-",prediction)
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# C4.5 algorithm
#
# 26-01-19 08:10:29 - C4.5 tree is going to be built...
# 26-01-19 08:10:30 - -------------------------
# 26-01-19 08:10:30 - finished in 0.633936882019043 seconds
# 26-01-19 08:10:30 - -------------------------
# 26-01-19 08:10:30 - Evaluate train set
# 26-01-19 08:10:30 - -------------------------
# 26-01-19 08:10:30 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:10:30 - Labels: ['No' 'Yes']
# 26-01-19 08:10:30 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:10:30 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':

# %%
print("CART algorithm\n")

#set algorithm
config = {'algorithm': 'CART'}
model = chef.fit(df[:8], config)

#define single x vector
xrow = ['Sunny','Hot','High','Weak']

#make single prediction
prediction = chef.predict(model, xrow)

#prediction on test data set
print("\nCompare predictions and expected results on TESTING dataset:")
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    
    print(actual,"-",prediction)
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# CART algorithm
#
# 26-01-19 08:10:39 - CART tree is going to be built...
# 26-01-19 08:10:40 - -------------------------
# 26-01-19 08:10:40 - finished in 0.8612358570098877 seconds
# 26-01-19 08:10:40 - -------------------------
# 26-01-19 08:10:40 - Evaluate train set
# 26-01-19 08:10:40 - -------------------------
# 26-01-19 08:10:40 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:10:40 - Labels: ['No' 'Yes']
# 26-01-19 08:10:40 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:10:40 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
#
# Compare predictions and expected results on TESTING dataset:
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':

# %%
import pandas as pd
from sklearn.datasets import load_iris
url = 'https://raw.githubusercontent.com/lenhattung/SP26-AI1904-DAP391m/refs/heads/main/lab_part_3/lab1/lab1/dataset/iris.data'
df=pd.read_csv(url)
df = df.sample(frac=1).reset_index(drop=True)
df.head()

print("ID3 algorithm\n")

#set algorithm
config = {'algorithm': 'ID3'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']  
    #print(actual,"-",prediction)
    
print("C4.5 algorithm\n")

#set algorithm
config = {'algorithm': 'C4.5'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    print(actual,"-",prediction)
    
print("CART algorithm\n")

#set algorithm
config = {'algorithm': 'CART'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    #print(actual,"-",prediction)
# Out:
# ID3 algorithm
#
# 26-01-19 08:12:35 - ID3 tree is going to be built...
# 26-01-19 08:12:38 - -------------------------
# 26-01-19 08:12:38 - finished in 3.0379416942596436 seconds
# 26-01-19 08:12:38 - -------------------------
# 26-01-19 08:12:38 - Evaluate train set
# 26-01-19 08:12:38 - -------------------------
# Iris-virginica - Iris-versicolor
# Iris-virginica - Iris-versicolor
# Iris-virginica - Iris-virginica
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-versicolor - Iris-versicolor
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-setosa - Iris-setosa
# Iris-versicolor - Iris-versicolor
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-virginica - Iris-versicolor
# CART algorithm
#
# 26-01-19 08:12:40 - CART tree is going to be built...
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# 26-01-19 08:12:42 - -------------------------
# 26-01-19 08:12:42 - finished in 2.280848979949951 seconds
# 26-01-19 08:12:42 - -------------------------
# 26-01-19 08:12:42 - Evaluate train set
# 26-01-19 08:12:42 - -------------------------
# 26-01-19 08:12:42 - Accuracy: 99.0% on 100 instances
# 26-01-19 08:12:42 - Labels: ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa']
# 26-01-19 08:12:42 - Confusion matrix: [[36, 1, 0], [0, 34, 0], [0, 0, 29]]
# 26-01-19 08:12:42 - Decision Iris-virginica
# 26-01-19 08:12:42 - Accuracy: 99.0
# 26-01-19 08:12:42 - Precision: 97.2973%, Recall: 100.0%, F1: 98.6301%
# 26-01-19 08:12:42 - Decision Iris-versicolor
# 26-01-19 08:12:42 - Accuracy: 99.0
# 26-01-19 08:12:42 - Precision: 100.0%, Recall: 97.1429%, F1: 98.5507%
# 26-01-19 08:12:42 - Decision Iris-setosa
# 26-01-19 08:12:42 - Accuracy: 100.0
# 26-01-19 08:12:42 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':
# c:\Users\Asus\OneDrive\Desktop\FPTU\DAP\Sklearn\LAB\LAB 3\outputs\rules\rules.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:

# %%
#implementation details at https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

from sklearn.datasets import load_iris
from sklearn import tree
X, y = load_iris(return_X_y=True)
tSize=int(X.shape[0]*0.9)
print(tSize)
X_train=X[0:tSize,:]
y_train=y[0:tSize]

X_test=X[tSize:,:]
y_test=y[tSize:]

clf = tree.DecisionTreeClassifier()

#train decision tree on training set
clf = clf.fit(X_train, y_train)

#predict values on testing set
y_pred=clf.predict(X_test);



tree.plot_tree(clf) 
#!pip install graphviz

from sklearn.metrics import classification_report, confusion_matrix

print("Confusion matrix results:")
print(confusion_matrix(y_test,y_pred))

print("Classification report")
print(classification_report(y_test, y_pred))
# Out:
# 135
# Confusion matrix results:
# [[15]]
# Classification report
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00        15
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
